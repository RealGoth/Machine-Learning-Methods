# %% [markdown]
# Ким Р.И. ИУ5-62Б Вариант №10

# %% [markdown]
# Задача №2

# %% [markdown]
# Для заданного набора данных проведите обработку пропусков в данных для одного категориального и одного количественного признака. Какие способы обработки пропусков в данных для категориальных и количественных признаков Вы использовали? Какие признаки Вы будете использовать для дальнейшего построения моделей машинного обучения и почему?

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Извлечение dataset

# %%
import os
import zipfile

DATA_PATH = os.path.join('datasets')

def fetch_data(data_path=DATA_PATH):
    os.makedirs(data_path, exist_ok=True)
    zip_path = os.path.join(data_path, 'dc-wikia-data.csv.zip')
    data_zip = zipfile.ZipFile(zip_path)
    data_zip.extractall(path=data_path)
    data_zip.close()

# %%
fetch_data()

# %%
def load_data(data_path=DATA_PATH):
    csv_path = os.path.join(data_path, 'dc-wikia-data.csv')
    return pd.read_csv(csv_path)

# %%
data = load_data()
data
# Out:
#       page_id                          name  \
# 0        1422          Batman (Bruce Wayne)
# 1       23387         Superman (Clark Kent)
# 2        1458    Green Lantern (Hal Jordan)
# 3        1659      James Gordon (New Earth)
# 4        1576   Richard Grayson (New Earth)
# ...       ...                           ...
# 6891    66302       Nadine West (New Earth)
# 6892   283475    Warren Harding (New Earth)
# 6893   283478  William Harrison (New Earth)
# 6894   283471  William McKinley (New Earth)
# 6895   150660            Mookie (New Earth)
#
#                                    urlslug               ID            ALIGN  \
# 0             \/wiki\/Batman_(Bruce_Wayne)  Secret Identity  Good Characters
# 1            \/wiki\/Superman_(Clark_Kent)  Secret Identity  Good Characters
# 2       \/wiki\/Green_Lantern_(Hal_Jordan)  Secret Identity  Good Characters
# 3         \/wiki\/James_Gordon_(New_Earth)  Public Identity  Good Characters
# ...

# %% [markdown]
# Проверка пропусков

# %%
data.isnull().sum()
# Out:
# page_id                0
# name                   0
# urlslug                0
# ID                  2013
# ALIGN                601
# EYE                 3628
# HAIR                2274
# SEX                  125
# GSM                 6832
# ALIVE                  3
# APPEARANCES          355
# FIRST APPEARANCE      69
# YEAR                  69
# dtype: int64

# %% [markdown]
# Категориальный признак - в EYE заменим пропуски самым непопулярным признаком

# %%
eye = data['EYE'].value_counts()
eye
# Out:
# Blue Eyes             1102
# Brown Eyes             879
# Black Eyes             412
# Green Eyes             291
# Red Eyes               208
# White Eyes             116
# Yellow Eyes             86
# Photocellular Eyes      48
# Grey Eyes               40
# Hazel Eyes              23
# Purple Eyes             14
# Violet Eyes             12
# Orange Eyes             10
# Gold Eyes                9
# Auburn Hair              7
# Pink Eyes                6
# Amber Eyes               5
# Name: EYE, dtype: int64

# %% [markdown]
# Самый непопулярный признак - Amber Eyes

# %%
data['EYE'].fillna('Amber Eyes', inplace=True)
data
# Out:
#       page_id                          name  \
# 0        1422          Batman (Bruce Wayne)
# 1       23387         Superman (Clark Kent)
# 2        1458    Green Lantern (Hal Jordan)
# 3        1659      James Gordon (New Earth)
# 4        1576   Richard Grayson (New Earth)
# ...       ...                           ...
# 6891    66302       Nadine West (New Earth)
# 6892   283475    Warren Harding (New Earth)
# 6893   283478  William Harrison (New Earth)
# 6894   283471  William McKinley (New Earth)
# 6895   150660            Mookie (New Earth)
#
#                                    urlslug               ID            ALIGN  \
# 0             \/wiki\/Batman_(Bruce_Wayne)  Secret Identity  Good Characters
# 1            \/wiki\/Superman_(Clark_Kent)  Secret Identity  Good Characters
# 2       \/wiki\/Green_Lantern_(Hal_Jordan)  Secret Identity  Good Characters
# 3         \/wiki\/James_Gordon_(New_Earth)  Public Identity  Good Characters
# ...

# %% [markdown]
# Проверка Amber Eyes

# %%
eye = data['EYE'].value_counts()
eye
# Out:
# Amber Eyes            3633
# Blue Eyes             1102
# Brown Eyes             879
# Black Eyes             412
# Green Eyes             291
# Red Eyes               208
# White Eyes             116
# Yellow Eyes             86
# Photocellular Eyes      48
# Grey Eyes               40
# Hazel Eyes              23
# Purple Eyes             14
# Violet Eyes             12
# Orange Eyes             10
# Gold Eyes                9
# Auburn Hair              7
# Pink Eyes                6
# Name: EYE, dtype: int64

# %% [markdown]
# Количественный признак - в APPEARANCES нулевые значения заменим средним

# %%
mean = data['APPEARANCES'].mean()
data['APPEARANCES'].fillna(mean, inplace=True)
data
# Out:
#       page_id                          name  \
# 0        1422          Batman (Bruce Wayne)
# 1       23387         Superman (Clark Kent)
# 2        1458    Green Lantern (Hal Jordan)
# 3        1659      James Gordon (New Earth)
# 4        1576   Richard Grayson (New Earth)
# ...       ...                           ...
# 6891    66302       Nadine West (New Earth)
# 6892   283475    Warren Harding (New Earth)
# 6893   283478  William Harrison (New Earth)
# 6894   283471  William McKinley (New Earth)
# 6895   150660            Mookie (New Earth)
#
#                                    urlslug               ID            ALIGN  \
# 0             \/wiki\/Batman_(Bruce_Wayne)  Secret Identity  Good Characters
# 1            \/wiki\/Superman_(Clark_Kent)  Secret Identity  Good Characters
# 2       \/wiki\/Green_Lantern_(Hal_Jordan)  Secret Identity  Good Characters
# 3         \/wiki\/James_Gordon_(New_Earth)  Public Identity  Good Characters
# ...

# %% [markdown]
# Проверка пропусков

# %%
data.isnull().sum()
# Out:
# page_id                0
# name                   0
# urlslug                0
# ID                  2013
# ALIGN                601
# EYE                    0
# HAIR                2274
# SEX                  125
# GSM                 6832
# ALIVE                  3
# APPEARANCES            0
# FIRST APPEARANCE      69
# YEAR                  69
# dtype: int64

# %% [markdown]
# Диаграмма рассеяния

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
sns.set(style='ticks')

# %%
PROJECT_ROOT_DIR = "."

def image_path(fig_id):
    return os.path.join(PROJECT_ROOT_DIR, "images", fig_id)

def save_fig(fig_id, tight_layout=True):
    os.makedirs("images", exist_ok=True)
    print("Saveing figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(image_path(fig_id) + ".png", format="png", dpi=300)

# %%
data.plot(kind='scatter', x='APPEARANCES', y='YEAR')
plt.legend(fontsize=15)
save_fig("APPEARANCES")
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# No handles with labels found to put in legend.
# Saveing figure APPEARANCES
